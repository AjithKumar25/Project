# %%
import pandas as pd
import numpy as np

print("Imported Successfully....!")
# Out:
# Imported Successfully....!

# %%
df=pd.read_csv("District_wise_crimes.csv")

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9017 entries, 0 to 9016
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9017 non-null   object
#  1   DISTRICT                                             9017 non-null   object
#  2   YEAR                                                 9017 non-null   int64
#  3   MURDER                                               9017 non-null   int64
#  4   ATTEMPT TO MURDER                                    9017 non-null   int64
#  5   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            9017 non-null   int64
#  6   RAPE                                                 9017 non-null   int64
#  7   CUSTODIAL RAPE                                       9017 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# STATE/UT                                               0
# DISTRICT                                               0
# YEAR                                                   0
# MURDER                                                 0
# ATTEMPT TO MURDER                                      0
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              0
# RAPE                                                   0
# CUSTODIAL RAPE                                         0
# OTHER RAPE                                             0
# KIDNAPPING & ABDUCTION                                 0
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            0
# KIDNAPPING AND ABDUCTION OF OTHERS                     0
# DACOITY                                                0
# PREPARATION AND ASSEMBLY FOR DACOITY                   0
# ROBBERY                                                0
# BURGLARY                                               0
# ...

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
df['STATE/UT'].value_counts()
# Out:
# UTTAR PRADESH        878
# MADHYA PRADESH       628
# MAHARASHTRA          552
# BIHAR                540
# TAMIL NADU           469
# RAJASTHAN            454
# ODISHA               430
# KARNATAKA            399
# GUJARAT              384
# ANDHRA PRADESH       370
# ASSAM                362
# JAMMU & KASHMIR      322
# PUNJAB               314
# JHARKHAND            312
# WEST BENGAL          309
# HARYANA              268
# CHHATTISGARH         266
# KERALA               233
# ARUNACHAL PRADESH    195
# DELHI UT             183
# HIMACHAL PRADESH     176
# UTTARAKHAND          168
# NAGALAND             138
# MANIPUR              125
# MIZORAM              108
# MEGHALAYA             96
# TRIPURA               67
# SIKKIM                60
# A & N ISLANDS         36
# GOA                   36
# DAMAN & DIU           36
# PUDUCHERRY            31
# LAKSHADWEEP           24
# D & N HAVELI          24
# CHANDIGARH            24
# Name: STATE/UT, dtype: int64

# %%
df.describe()
# Out:
#               YEAR      MURDER  ATTEMPT TO MURDER  \
# count  9017.000000  9017.00000        9017.000000
# mean   2006.629034    89.28535          78.069646
# std       3.463623   327.27503         303.446020
# min    2001.000000     0.00000           0.000000
# 25%    2004.000000    18.00000          10.000000
# 50%    2007.000000    38.00000          28.000000
# 75%    2010.000000    66.00000          56.000000
# max    2012.000000  7601.00000        7964.000000
#
#        CULPABLE HOMICIDE NOT AMOUNTING TO MURDER         RAPE  CUSTODIAL RAPE  \
# count                                9017.000000  9017.000000     9017.000000
# mean                                    9.895531    53.041366        0.005767
# std                                    59.521657   190.741450        0.115223
# min                                     0.000000     0.000000        0.000000
# 25%                                     0.000000     8.000000        0.000000
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
## Visualize the ordinal variables
df['STATE/UT'].value_counts(normalize=True).plot.bar(figsize=(12,5), title='States',color=['green','blue','yellow','cyan'])
plt.show()

# %%
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
from pandas.plotting import scatter_matrix

# %%
##seaborn countplot
plt.subplots(figsize=(22,18))
sns.countplot(y='YEAR',hue='STATE/UT',data=df, palette='Set3')
plt.title("Property_Area vs Loan_status")
plt.show()

# %%
#Scatter plot
plt.scatter(x='YEAR', y='MURDER', data=df)
plt.title('Year vs MURDER CASES')
# Out:
# Text(0.5, 1.0, 'Year vs MURDER CASES')

# %%
#seaborn
plt.subplots(figsize=(12,8))
sns.barplot(y="STATE/UT", x='MURDER', data=df)
plt.show()

# %%
## removing skewness using log transforms
## Before log transformation
df.hist(column=['RAPE']) ## Train data
plt.show()

# %%
## removing skewness using log transforms
## Before log transformation
df.hist(column=['ROBBERY']) ## Train data
plt.show()

# %%
#Scatter plot
plt.scatter(x='MURDER', y='OTHER RAPE', data=df)
plt.title('YEAR vs MURDER CASES')
plt.show()

# %%
#seaborn
plt.subplots(figsize=(12,8))
sns.barplot(y="STATE/UT", x='CAUSING DEATH BY NEGLIGENCE', data=df)
# Out:
# <AxesSubplot:xlabel='CAUSING DEATH BY NEGLIGENCE', ylabel='STATE/UT'>

# %%
df['STATE/UT'].value_counts().to_dict()
# Out:
# {'UTTAR PRADESH': 878,
#  'MADHYA PRADESH': 628,
#  'MAHARASHTRA': 552,
#  'BIHAR': 540,
#  'TAMIL NADU': 469,
#  'RAJASTHAN': 454,
#  'ODISHA': 430,
#  'KARNATAKA': 399,
#  'GUJARAT': 384,
#  'ANDHRA PRADESH': 370,
#  'ASSAM': 362,
#  'JAMMU & KASHMIR': 322,
#  'PUNJAB': 314,
#  'JHARKHAND': 312,
#  'WEST BENGAL': 309,
#  'HARYANA': 268,
#  'CHHATTISGARH': 266,
#  'KERALA': 233,
#  'ARUNACHAL PRADESH': 195,
#  'DELHI UT': 183,
#  'HIMACHAL PRADESH': 176,
#  'UTTARAKHAND': 168,
#  'NAGALAND': 138,
#  'MANIPUR': 125,
#  'MIZORAM': 108,
#  'MEGHALAYA': 96,
#  'TRIPURA': 67,
#  'SIKKIM': 60,
#  'A & N ISLANDS': 36,
#  'GOA': 36,
#  'DAMAN & DIU': 36,
#  'PUDUCHERRY': 31,
#  'LAKSHADWEEP': 24,
#  'D & N HAVELI': 24,
#  'CHANDIGARH': 24}

# %%
from sklearn.preprocessing import LabelEncoder

# %%
gle=LabelEncoder()
STATE=gle.fit_transform(df['STATE/UT'])
state={index: label for index, label in enumerate(gle.classes_)}

# %%
state
# Out:
# {0: 'A & N ISLANDS',
#  1: 'ANDHRA PRADESH',
#  2: 'ARUNACHAL PRADESH',
#  3: 'ASSAM',
#  4: 'BIHAR',
#  5: 'CHANDIGARH',
#  6: 'CHHATTISGARH',
#  7: 'D & N HAVELI',
#  8: 'DAMAN & DIU',
#  9: 'DELHI UT',
#  10: 'GOA',
#  11: 'GUJARAT',
#  12: 'HARYANA',
#  13: 'HIMACHAL PRADESH',
#  14: 'JAMMU & KASHMIR',
#  15: 'JHARKHAND',
#  16: 'KARNATAKA',
#  17: 'KERALA',
#  18: 'LAKSHADWEEP',
#  19: 'MADHYA PRADESH',
#  20: 'MAHARASHTRA',
#  21: 'MANIPUR',
#  22: 'MEGHALAYA',
#  23: 'MIZORAM',
#  24: 'NAGALAND',
#  25: 'ODISHA',
#  26: 'PUDUCHERRY',
#  27: 'PUNJAB',
#  28: 'RAJASTHAN',
#  29: 'SIKKIM',
#  30: 'TAMIL NADU',
#  31: 'TRIPURA',
#  32: 'UTTAR PRADESH',
#  33: 'UTTARAKHAND',
#  34: 'WEST BENGAL'}

# %%
gle=LabelEncoder()
DISTRICTS=gle.fit_transform(df['DISTRICT'])
district={index: label for index, label in enumerate(gle.classes_)}

# %%
district
# Out:
# {0: '24 PARGANAS NORTH',
#  1: '24 PARGANAS SOUTH',
#  2: 'A and N ISLANDS',
#  3: 'ADILABAD',
#  4: 'AGRA',
#  5: 'AHMEDABAD COMMR.',
#  6: 'AHMEDABAD RURAL',
#  7: 'AHMEDNAGAR',
#  8: 'AHWA-DANG',
#  9: 'AIZAWL',
#  10: 'AJMER',
#  11: 'AKOLA',
#  12: 'ALAPUZHA',
#  13: 'ALIGARH',
#  14: 'ALIRAJPUR',
#  15: 'ALLAHABAD',
#  16: 'ALMORA',
#  17: 'ALWAR',
#  18: 'AMBALA',
#  19: 'AMBALA RURAL',
#  20: 'AMBALA URBAN',
#  21: 'AMBEDKAR NAGAR',
#  22: 'AMRAVATI COMMR.',
#  23: 'AMRAVATI RURAL',
#  24: 'AMRELI',
#  25: 'AMRITSAR',
#  26: 'AMRITSAR RURAL',
#  27: 'ANAND',
#  28: 'ANANTAPUR',
#  29: 'ANANTNAG',
#  30: 'ANDAMAN',
#  31: 'ANGUL',
#  32: 'ANJAW',
#  33: 'ANUPPUR',
#  34: 'ARARIA',
#  35: 'ARIYALUR',
#  36: 'ARWAL',
#  37: 'ASANSOL',
#  38: 'ASHOK NAGAR',
#  39: 'AURAIYA',
#  40: 'AURANGABAD',
#  41: 'AURANGABAD COMMR.',
#  42: 'AURANGABAD RURAL',
#  43: 'AWANTIPORA',
#  44: 'AZAMGARH',
#  45: 'BADAUN',
#  46: 'BADDIPOLICEDIST',
#  47: 'BAGAHA',
#  48: 'BAGALKOT',
# ...

# %%
df['STATE/UT']=STATE

# %%
df['DISTRICT']=DISTRICTS

# %%
df.head()
# Out:
#    STATE/UT  DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0         1         3  2001     101                 60
# 1         1        28  2001     151                125
# 2         1       154  2001     101                 57
# 3         1       172  2001      80                 53
# 4         1       220  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
# 1          23                      53  ...     69                1543
# ...
